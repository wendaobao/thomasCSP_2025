# %% [markdown]
# ---
# layout: tailwind
# title: V-Card
# description: Digital business card with contact information
# type: issues
# ---

# %% [markdown]
# <div class="min-h-screen bg-gradient-to-br from-white via-blue-50 to-blue-100 flex items-center justify-center px-4 py-16">
#   <div class="w-full max-w-5xl bg-white/80 backdrop-blur-lg rounded-3xl shadow-xl p-10">
#     <!-- Profile Header -->
#     <div class="flex flex-col md:flex-row items-center md:items-start gap-8">
#       <img src="https://i.postimg.cc/4yDYy3Y9/IMG-5001-2.jpg" alt="Wendao Bao" class="w-32 h-32 rounded-xl shadow-lg object-cover" />
#       <div class="flex-1 text-center md:text-left">
#         <h1 class="text-3xl font-extrabold text-gray-800">Wendao Bao</h1>
#         <p class="text-gray-600 text-sm mt-1">Developer • Innovator • Student</p>
#         <div class="mt-4 flex flex-wrap gap-4 justify-center md:justify-start text-sm text-gray-700">
#           <a href="mailto:wendaobao@gmail.com" class="flex items-center gap-2 hover:underline">
#             <img src="https://img.icons8.com/color/24/gmail.png"/> wendaobao@gmail.com
#           </a>
#           <a href="https://www.linkedin.com/in/wendao-bao-225180368/" target="_blank" class="flex items-center gap-2 hover:underline">
#             <img src="https://img.icons8.com/color/24/linkedin.png"/> LinkedIn
#           </a>
#           <a href="https://github.com/wendaobao" target="_blank" class="flex items-center gap-2 hover:underline">
#             <img src="https://img.icons8.com/material-outlined/24/github.png"/> GitHub
#           </a>
#           <a href="https://www.instagram.com/therealthomasbao?igsh=NTc4MTIwNjQ2YQ%3D%3D&utm_source=qr" target="_blank" class="flex items-center gap-2 hover:underline">
#             <img src="https://img.icons8.com/color/24/instagram-new.png"/> Instagram
#           </a>
#         </div>
#       </div>
#     </div>
#
#     <!-- Cards Section -->
#     <div class="grid grid-cols-1 md:grid-cols-2 gap-8 mt-10">
#       <!-- Left: Contact & Button -->
#       <div class="bg-white rounded-2xl p-6 shadow-md border border-gray-100 flex flex-col justify-between">
#         <div>
#           <h2 class="text-xl font-semibold text-gray-800 mb-4">Contact Me</h2>
#           <ul class="space-y-3 text-gray-600">
#             <li><strong>Email:</strong> wendaobao@gmail.com</li>
#             <li><strong>Portfolio:</strong> <a href="https://github.com/wendaobao" class="text-blue-600 hover:underline" target="_blank">GitHub Site</a></li>
#             <li><strong>LinkedIn:</strong> <a href="https://www.linkedin.com/in/wendao-bao-225180368/" class="text-blue-600 hover:underline" target="_blank">View Profile</a></li>
#           </ul>
#         </div>
#         <div class="mt-6 text-center">
#           <button onclick="downloadVCard()" class="bg-blue-600 hover:bg-blue-700 text-white text-sm font-semibold px-6 py-2 rounded-full shadow-lg transition-transform hover:scale-105">
#             📄 Download vCard
#           </button>
#         </div>
#       </div>
#
#       <!-- Right: QR Codes -->
#       <div class="bg-white rounded-2xl p-6 shadow-md border border-gray-100">
#         <h2 class="text-xl font-semibold text-gray-800 mb-6 text-center">Quick Connect</h2>
#         <div class="flex flex-col items-center gap-6">
#           <div class="text-center">
#             <img src="https://i.postimg.cc/cC8TzTPG/Screenshot-2025-06-05-at-6-34-50-PM.png" alt="vCard QR" class="w-40 h-40 rounded-lg shadow border border-gray-200">
#             <p class="text-sm text-gray-500 mt-2">This Page</p>
#           </div>
#           <div class="text-center">
#             <img src="https://i.postimg.cc/mZNSPzRw/Screenshot-2025-06-05-at-6-35-36-PM.png" alt="Website QR" class="w-40 h-40 rounded-lg shadow border border-gray-200">
#             <p class="text-sm text-gray-500 mt-2">Portfolio Website</p>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div>
#
# <script>
# function downloadVCard() {
#   const vCardData = `BEGIN:VCARD
# VERSION:3.0
# FN:Wendao Bao
# EMAIL:wendaobao@gmail.com
# URL:https://github.com/wendaobao
# NOTE:Connect with me via LinkedIn, GitHub, or check out my portfolio!
# END:VCARD`;
#   const blob = new Blob([vCardData], { type: 'text/vcard' });
#   const url = URL.createObjectURL(blob);
#   const a = document.createElement('a');
#   a.href = url;
#   a.download = 'wendao-bao.vcf';
#   document.body.appendChild(a);
#   a.click();
#   document.body.removeChild(a);
#   URL.revokeObjectURL(url);
# }
# </script>
